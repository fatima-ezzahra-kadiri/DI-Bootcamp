# %% [markdown]
# <h1 style="text-align:center; color:red;">Exercises XP</h1>

# %% [markdown]
# Exercise 1: What Are You Learning?
# Goal: Create a function that displays a message about what you’re learning.

# %%
def display_message():
    print("I am learning about functions in Python.")
    
display_message()
# Out:
# I am learning about functions in Python.

# %% [markdown]
# Exercise 2: What’s Your Favorite Book?
# Goal: Create a function that displays a message about a favorite book.

# %%
def favorite_book(title):
    print(f"One of my favorite books is {title}")

favorite_book("Les fleurs du mal")
# Out:
# One of my favorite books is Les fleurs du mal

# %% [markdown]
# Exercise 3: Some Geography
# Goal: Create a function that describes a city and its country.

# %%
def describe_city(city, country="Unknown"):
    print(f"{city} is in {country}")
    
describe_city("Rabat", country="Morocco")
# Out:
# Rabat is in Morocco

# %%
def describe_city(city, country="Unknown"):
    print(f"{city} is in {country}")
    
describe_city("London", "England")
# Out:
# London is in England

# %%
def describe_city(city, country="Unknown"):
    print(f"{city} is in {country}")
    
describe_city("Mosco")
# Out:
# Mosco is in Unknown

# %% [markdown]
#  Exercise 4: Random
# Goal: Create a function that generates random numbers and compares them.

# %%
import random
def function_rand(a):
    b = random.randint(1, 100)
    if a==b:
        print("success")
    else:
        print(f"fail, your number is {a} is different of the generated number {b}")

function_rand(7)
# Out:
# fail, your number is 7 is different of the generated number 27

# %% [markdown]
# Exercise 5: Let’s Create Some Personalized Shirts!
# Goal: Create a function to describe a shirt’s size and message, with default values.

# %%
def make_shirt(size, text="I love Python"):
    print(f"The size of the shirt is {size} and the text is {text}.")

make_shirt("large")
make_shirt("medium")
make_shirt("small", "Be Happy, life is beautiful")
# Out:
# The size of the shirt is large and the text is I love Python.
# The size of the shirt is medium and the text is I love Python.
# The size of the shirt is small and the text is Be Happy, life is beautiful.

# %% [markdown]
# Exercise 6: Magicians…
# Goal: Modify a list of magician names and display them in different ways.

# %%
magician_names=['Harry Houdini', 'David Blaine', 'Criss Angel']

def show_magicians(magician_names):
    for i in magician_names:
        print(i)

def make_great(magician_names):
    for i in range(len(magician_names)):
        magician_names[i] = "the Great " + magician_names[i]
        
         

make_great(magician_names)
show_magicians(magician_names)
# Out:
# the Great Harry Houdini
# the Great David Blaine
# the Great Criss Angel

# %% [markdown]
# Exercise 7: Temperature Advice
# Goal: Generate a random temperature and provide advice based on the temperature range.

# %%
def get_random_temp():
    return random.randint(-10, 40)

def main():
    temp = get_random_temp()
    print(f"The temperature right now is {temp} degrees Celsius.")
    if temp<=0:
        print("Brrr, that’s freezing! Wear some extra layers today.")
    elif temp>0 and temp<=16:
        print("Quite chilly! Don’t forget your coat.")
    elif temp>16 and temp<=23:
        print("Nice weather.")
    elif temp>23 and temp<=32:
        print("A bit warm, stay hydrated.")
    else:
        print("It’s really hot! Stay cool.")

main()
# Out:
# The temperature right now is 24 degrees Celsius.
# A bit warm, stay hydrated.

# %%
def get_random_temp():
    return random.uniform(-10, 40)

def main():
    temp = get_random_temp()
    print(f"The temperature right now is {round(temp,2)} degrees Celsius.")
    if temp<=0:
        print("Brrr, that’s freezing! Wear some extra layers today.")
    elif temp>0 and temp<=16:
        print("Quite chilly! Don’t forget your coat.")
    elif temp>16 and temp<=23:
        print("Nice weather.")
    elif temp>23 and temp<=32:
        print("A bit warm, stay hydrated.")
    else:
        print("It’s really hot! Stay cool.")

main()
# Out:
# The temperature right now is 4.02 degrees Celsius.
# Quite chilly! Don’t forget your coat.

# %%
def get_random_temp(month):
     
    if month in [3, 4, 5]:
        return [random.uniform(24, 32), "spring"]
    if month in [6, 7, 8]:
        return [random.uniform(32, 40), "summer"]
    if month in [9, 10, 11]:
        return [random.uniform(0, 16), "autumn"]
    if month in [12, 1, 2]:
        return [random.uniform(-10, 0), "winter"]
   

def main():
    month = int(input("enter the current month (between 1et 12): "))
    temp = get_random_temp(month)[0]
    saison = get_random_temp(month)[1]
    print(f"The saison now is {saison}")
    print(f"The temperature right now is {round(temp,2)} degrees Celsius.")
    if temp<=0:
        print("Brrr, that’s freezing! Wear some extra layers today.")
    elif temp>0 and temp<=16:
        print("Quite chilly! Don’t forget your coat.")
    elif temp>16 and temp<=23:
        print("Nice weather.")
    elif temp>23 and temp<=32:
        print("A bit warm, stay hydrated.")
    else:
        print("It’s really hot! Stay cool.")

main()
# Out:
# enter the current month (between 1et 12):  4
# The saison now is spring
# The temperature right now is 31.87 degrees Celsius.
# A bit warm, stay hydrated.
