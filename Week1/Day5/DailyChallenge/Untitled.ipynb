# %% [markdown]
# <h1 style="text-align:center; color:red;">Daily Challenge</h1>

# %% [markdown]
# <h2 style="text-align:left; color:green;">Challenge 1: Sorting</h2>

# %% [markdown]
# Instructions:
#
# Write a Python program that takes a single string of words as input, where the words are separated by commas (e.g., ‘apple,banana,cherry’). The program should output these words sorted in alphabetical order, with the sorted words also separated by commas.

# %%
words = input("enter a single string of words:")
# Out:
# enter a single string of words: banana,apple,cherry,avocado

# %%
L = words.split(",")

# %%
L
# Out:
# ['banana', 'apple', 'cherry', 'avocado']

# %%
L.sort()

# %%
L
# Out:
# ['apple', 'avocado', 'banana', 'cherry']

# %%
output = ",".join(L)

# %%
output
# Out:
# 'apple,avocado,banana,cherry'

# %% [markdown]
# <h2 style="text-align:left; color:green;">Challenge 2: Longest Word</h2>

# %% [markdown]
# Instructions:
#
# Write a function that takes a sentence as input and returns the longest word in the sentence. If there are multiple longest words, return the first one encountered. Characters like apostrophes, commas, and periods should be considered part of the word.

# %%
def longestword(sentence):
    #sentence = input("enter sentence:")
    Liste = sentence.split(" ")
    LW = Liste[0]
    for i in range(1,len(Liste)):
        if len(LW)< len(Liste[i]):
            LW = Liste[i]
    return LW

# %%
sentence= "Margaret's toy is a pretty doll."

# %%
longestword(sentence)
# Out:
# "Margaret's"
