# %% [markdown]
# <h1 style="text-align:center; color:red;">Exercise XP</h1>

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 1: Hello World</h2>

# %%
print("Hello world\n"*4)
# Out:
# Hello world
# Hello world
# Hello world
# Hello world

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 2: Some Math</h2>

# %%
result = (99**3)*8
result
# Out:
# 7762392

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 3: What is the output?</h2>

# %% [raw]
# >>> 5 < 3
# False, because 5 est grather than 3
#
# >>> 3 == 3
# # True, the twice values are equals
#
# >>> 3 == "3"
# # False, 3 is int or "3" is string
#
# >>> "3" > 3
# # Erreur TypeError, wa can't campare string and int
#
# >>> "Hello" == "hello"
# # False, Python is case sensitive (H != h)

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 4: Your computer brand</h2>

# %% [raw]
# Instructions
# Create a variable called computer_brand which value is the brand name of your computer.
# Using the computer_brand variable, print a sentence that states the following:
# "I have a <computer_brand> computer."

# %%
computer_brand = "Lenovo"
print(f"I have a {computer_brand} computer.")
print("I have a {} computer.".format(computer_brand))
print("I have a " + computer_brand + " computer.")
# Out:
# I have a Lenovo computer.
# I have a Lenovo computer.
# I have a Lenovo computer.

# %% [markdown]
# <h2 style="text-align:left; color:green;"> Exercise 5: Your information</h2>

# %% [raw]
# Instructions
# Create a variable called name, and set it’s value to your name.
# Create a variable called age, and set it’s value to your age.
# Create a variable called shoe_size, and set it’s value to your shoe size.
# Create a variable called info and set it’s value to an interesting sentence about yourself. The sentence must contain all the variables created in parts 1, 2, and 3.
# Have your code print the info message.
# Run your code.

# %%
name = "fatima ezzahra"
age = "24"
shoe_size = "37"
info = "I am fatima ezzahra, I am 24 and my shoe size is 37"
print("I am {}, I am {} and my shoe size is {}".format(name, age, shoe_size))
# Out:
# I am fatima ezzahra kadiri, I am 24 and my shoe size is 37

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 6: A & B: Your computer brand</h2>

# %% [raw]
# Instructions
# Create two variables, a and b.
# Each variable’s value should be a number.
# If a is bigger than b, have your code print "Hello World".

# %%
a = 3
b = 7
if a > b:
    print("Hello Word")

# %%
a = 9
b = 7
if a > b:
    print("Hello Word")
# Out:
# Hello Word

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 7: Odd or Even</h2>

# %% [raw]
# Exercise 7: Odd or Even
# Instructions
# Write code that asks the user for a number and determines whether this number is odd or even.

# %%
a = int(input("enter a number:"))
if a % 2 == 0:
    print("this number is even")
else:
    print("this number us odd")
# Out:
# enter a number: 3
# this number us odd

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 8: What’s your name?</h2>

# %% [raw]
# Instructions
# Write code that asks the user for their name and determines whether or not you have the same name. Print out a funny message based on the outcome.

# %%
my_name = "fatima ezzahra"
user_name = input("print your name: ")
if my_name == user_name:
    print("nice, we have the same name")
else:
    print("you have a beautiful name")
# Out:
# print your name:  fatima ezzahra
# nice, we have the same name

# %%
my_name = "fatima ezzahra"
user_name = input("print your name: ")
if my_name == user_name:
    print("nice, we have the same name")
else:
    print("you have a beautiful name")
# Out:
# print your name:  sara
# you have a beautiful name

# %% [markdown]
# <h2 style="text-align:left; color:green;">Exercise 9: Tall enough to ride a roller coaster</h2>

# %% [raw]
# Instructions
# Write code that will ask the user for their height in centimeters.
# If they are over 145 cm, print a message that states they are tall enough to ride.
# If they are not tall enough, print a message that says they need to grow some more to ride.

# %%
height = float(input("print your height in centimeters: "))
if height > 145:
    print("You are tall enough to ride.")
else:
    print("you need to grow some more to ride.")
# Out:
# print your height in centimeters:  159
# You are tall enough to ride.
